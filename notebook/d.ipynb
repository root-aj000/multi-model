# %%
import os
from IPython.display import FileLink

# Verify the file path exists first
path = '/kaggle/working/saved_models/best_model_epoch_6_acc_0.6233.pt'

if os.path.exists(path):
    display(FileLink(path))
else:
    print("File not found. Double-check your path directory.")
# Out:
# File not found. Double-check your path directory.
