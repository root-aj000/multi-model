# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')

# %%
! git clone https://github.com/root-aj000/multi-model
# Out:
# Cloning into 'multi-model'...
# remote: Enumerating objects: 475, done.
# remote: Counting objects: 100% (475/475), done.
# remote: Compressing objects: 100% (373/373), done.
# remote: Total 475 (delta 111), reused 432 (delta 68), pack-reused 0 (from 0)
# Receiving objects: 100% (475/475), 16.93 MiB | 37.69 MiB/s, done.
# Resolving deltas: 100% (111/111), done.

# %%
# Install required dependencies from the project requirements file
import os
from pathlib import Path

repo_root = Path('/kaggle/working/multi-model')
requirements_path = repo_root / 'multi-model' / 'requirements.txt'
print('Requirements path:', requirements_path)

if requirements_path.exists():
    # !python -m pip install -r "{requirements_path}"
else:
    raise FileNotFoundError(f'Requirements file not found: {requirements_path}')
# Out:
# Requirements path: /kaggle/working/multi-model/multi-model/requirements.txt
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.4/395.4 kB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.9/152.9 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.5/153.5 kB 11.4 MB/s eta 0:00:00
# ...

# %%
import json
from pathlib import Path

config_file = Path('/kaggle/working/multi-model/multi-model/configs/model/model_config.json')
print('Config file:', config_file)

if not config_file.exists():
    raise FileNotFoundError(f'Config file not found: {config_file}')

config = json.loads(config_file.read_text())
config['DATASET_ROOT'] = '/kaggle/input/datasets/anishjagdaleaj/testdataset'

config_file.write_text(json.dumps(config, indent=2))
print('Updated DATASET_ROOT to:', config['DATASET_ROOT'])
# Out:
# Config file: /kaggle/working/multi-model/multi-model/configs/model/model_config.json
# Updated DATASET_ROOT to: /kaggle/input/datasets/anishjagdaleaj/testdataset

# %%
# import os
# import sys
# from pathlib import Path

# # 1. Define the physical path to check if the file exists
# # Adjust this to the EXACT location of the file on the disk
# script_physical_path = Path('/kaggle/working/multi-model/multi-model/scripts/train_model.py')
# config_path = Path('/kaggle/working/multi-model/multi-model/configs/model/model_config.json')

# if not script_physical_path.exists():
#     raise FileNotFoundError(f'File not found at: {script_physical_path}')

# # 2. Add the root directory to PYTHONPATH 
# # This allows 'python -m' to see the 'scripts' folder as a package
# root_dir = "/kaggle/working/multi-model"
# os.environ['PYTHONPATH'] = root_dir + ":" + os.environ.get('PYTHONPATH', '')

# # 3. Run using the module notation
# # If the file is at multi-model/scripts/train_model.py, the module is 'scripts.train_model'
# !python -m scripts.train_model --config "{config_path}" --epochs 2 --log-dir "local/logs"


import os
from pathlib import Path

# 1. Precise path based on your error log
# It seems you have a nested structure: multi-model/multi-model/scripts
script_physical_path = Path('/kaggle/working/multi-model/multi-model/scripts/train_model.py')
config_path = Path('/kaggle/working/multi-model/multi-model/configs/model/model_config.json')

if not script_physical_path.exists():
    raise FileNotFoundError(f'File not found at: {script_physical_path}')

# 2. Set the root to the folder that CONTAINS 'scripts'
# Since scripts is inside multi-model/multi-model/
root_dir = "/kaggle/working/multi-model/multi-model"
os.environ['PYTHONPATH'] = root_dir + ":" + os.environ.get('PYTHONPATH', '')

# 3. Verify if __init__.py exists (required for -m)
init_file = script_physical_path.parent / "__init__.py"
if not init_file.exists():
    print(f"Warning: Creating missing __init__.py in {script_physical_path.parent}")
    init_file.touch()

# 4. Run the module
# !python -m scripts.train_model --config "{config_path}" --epochs 10 --log-dir "local/logs"
# Out:
# INFO:lib.utils.config:Loaded config from /kaggle/working/multi-model/multi-model/configs/model/model_config.json
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/distilbert-base-uncased/resolve/main/config.json "HTTP/1.1 200 OK"
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/distilbert-base-uncased/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/distilbert/distilbert-base-uncased/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# ...
